# %% [markdown]
# <a href="https://colab.research.google.com/github/tasneem94/Bioactivity-Predicition-Thesis/blob/main/Thesis_01_Leukocyte_elastase_Data_Preprocessing_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 55 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 60 kB 6.2 MB/s
# ...
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('bone')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references           organism  \
# 0   [{'xref_id': 'P12644', 'xref_name': None, 'xre...       Homo sapiens
# 1                                                  []       Mus musculus
# 2                                                  []  Rattus norvegicus
# 3                                                  []       Homo sapiens
# 4                                                  []       Mus musculus
# 5                                                  []         Bos taurus
# 6                                                  []       Homo sapiens
# 7   [{'xref_id': 'Q13873', 'xref_name': None, 'xre...       Homo sapiens
# 8                                                  []       Mus musculus
# 9   [{'xref_id': 'P13497', 'xref_name': None, 'xre...       Homo sapiens
# 10                                                 []       Homo sapiens
# 11                                                 []       Homo sapiens
# ...

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[12]
selected_target
# Out:
# 'CHEMBL248'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#      activity_comment  activity_id  \
# 0                None        32937
# 1                None        35188
# 2                None        35192
# 3                None        35193
# 4                None        35431
# ...               ...          ...
# 3142             None     23296251
# 3143             None     23296252
# 3144             None     23296253
# 3145           Active     23333067
# 3146       Not Active     23333076
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL675350
# 1                                                    []    CHEMBL676202
# 2                                                    []    CHEMBL676203
# 3                                                    []    CHEMBL752072
# 4                                                    []    CHEMBL675350
# ...                                                 ...             ...
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('Leukocyte_elastase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#      activity_comment  activity_id  \
# 0                None        32937
# 1                None        35188
# 2                None        35192
# 3                None        35193
# 4                None        35431
# ...               ...          ...
# 3142             None     23296251
# 3143             None     23296252
# 3144             None     23296253
# 3145           Active     23333067
# 3146       Not Active     23333076
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL675350
# 1                                                    []    CHEMBL676202
# 2                                                    []    CHEMBL676203
# 3                                                    []    CHEMBL752072
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 2030

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#      activity_comment  activity_id  \
# 0                None        32937
# 1                None        35188
# 4                None        35431
# 5                None        46161
# 6                None        46174
# ...               ...          ...
# 3141             None     23296250
# 3142             None     23296251
# 3143             None     23296252
# 3144             None     23296253
# 3146       Not Active     23333076
#
#                                     activity_properties assay_chembl_id  \
# 0                                                    []    CHEMBL675350
# 1                                                    []    CHEMBL676202
# 4                                                    []    CHEMBL675350
# 5                                                    []    CHEMBL675350
# 6                                                    []    CHEMBL675350
# ...                                                 ...             ...
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL97927             O=C1C[C@H](Cc2ccccc2)N1C(=O)NCc1ccncc1
# 1          CHEMBL543416  CC(C)[C@@H]1C(=O)N(S(C)(=O)=O)[C@@H]2CCN(C(=O)...
# 4           CHEMBL95260    CS[C@@H]1C(=O)N(C(=O)NCc2ccncc2)[C@H]1Cc1ccccc1
# 5           CHEMBL95813  C=CC[C@@H]1C(=O)N(C(=O)NCc2ccncc2)[C@H]1Cc1ccccc1
# 6          CHEMBL330647     C[C@@H]1C(=O)N(C(=O)NCc2ccncc2)[C@H]1Cc1ccccc1
# ...                 ...                                                ...
# 3141      CHEMBL4855269  CC(C)C(NC(=O)[C@@H]1CCCN1C(=O)[C@@H](NC(=O)NC(...
# 3142      CHEMBL4874616  CCC(C)C(NC(=O)[C@@H]1CCCN1C(=O)[C@@H](NC(=O)NC...
# 3143      CHEMBL4879313  CC(C)C(NC(=O)[C@@H]1CCCN1C(=O)[C@@H](NC(=O)OCc...
# 3144      CHEMBL4847846  CCC(C)C(NC(=O)[C@@H]1CCCN1C(=O)[C@@H](NC(=O)OC...
# 3146      CHEMBL4520674  CC(=O)C1=C(C)N(c2cccc(C(F)(F)F)c2)C(=O)N[C@H]1...
#
#      standard_value
# 0           75000.0
# 1              11.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('Leukocyte_elastase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0           CHEMBL97927             O=C1C[C@H](Cc2ccccc2)N1C(=O)NCc1ccncc1
# 1          CHEMBL543416  CC(C)[C@@H]1C(=O)N(S(C)(=O)=O)[C@@H]2CCN(C(=O)...
# 2           CHEMBL95260    CS[C@@H]1C(=O)N(C(=O)NCc2ccncc2)[C@H]1Cc1ccccc1
# 3           CHEMBL95813  C=CC[C@@H]1C(=O)N(C(=O)NCc2ccncc2)[C@H]1Cc1ccccc1
# 4          CHEMBL330647     C[C@@H]1C(=O)N(C(=O)NCc2ccncc2)[C@H]1Cc1ccccc1
# ...                 ...                                                ...
# 2025      CHEMBL4855269  CC(C)C(NC(=O)[C@@H]1CCCN1C(=O)[C@@H](NC(=O)NC(...
# 2026      CHEMBL4874616  CCC(C)C(NC(=O)[C@@H]1CCCN1C(=O)[C@@H](NC(=O)NC...
# 2027      CHEMBL4879313  CC(C)C(NC(=O)[C@@H]1CCCN1C(=O)[C@@H](NC(=O)OCc...
# 2028      CHEMBL4847846  CCC(C)C(NC(=O)[C@@H]1CCCN1C(=O)[C@@H](NC(=O)OC...
# 2029      CHEMBL4520674  CC(=O)C1=C(C)N(c2cccc(C(F)(F)F)c2)C(=O)N[C@H]1...
#
#       standard_value         class
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('Leukocyte_elastase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip Leukocyte_elastase.zip *.csv
# Out:
#   adding: Leukocyte_elastase_01_bioactivity_data_raw.csv (deflated 94%)
#   adding: Leukocyte_elastase_02_bioactivity_data_preprocessed.csv (deflated 85%)
#   adding: Leukocyte_elastase_03_bioactivity_data_curated.csv (deflated 86%)

# %%
! ls -l
# Out:
# total 3052
# -rw-r--r-- 1 root root 2525277 Sep 28 11:23 Leukocyte_elastase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  183162 Sep 28 11:24 Leukocyte_elastase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  199552 Sep 28 11:27 Leukocyte_elastase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  205025 Sep 28 11:27 Leukocyte_elastase.zip
# drwxr-xr-x 1 root root    4096 Sep 26 13:45 sample_data

# %% [markdown]
# ---
