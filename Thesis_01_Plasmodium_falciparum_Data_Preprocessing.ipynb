# %% [markdown]
# <a href="https://colab.research.google.com/github/tasneem94/Bioactivity-Predicition-Thesis/blob/main/Thesis_01_Plasmodium_falciparum_Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2.3 million compounds. It is compiled from more than 85,000 documents, 1.5 million assays and the data spans 15,000 targets and 2,000 cells and 43,000 indications.
# [Data as of September 29, 2022; ChEMBL version 31].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Plasmodium falciparum**

# %%
# Target search for Plasmodium falciparum
target = new_client.target
target_query = target.search('Plasmodium falciparum')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                      cross_references  \
# 0                                                  []
# 1                                                  []
# 2                                                  []
# 3                                                  []
# 4                                                  []
# ..                                                ...
# 71  [{'xref_id': 'Q27744', 'xref_name': None, 'xre...
# 72                                                 []
# 73                                                 []
# 74                                                 []
# 75                                                 []
#
#                                organism  \
# 0                 Plasmodium falciparum
# 1             Plasmodium falciparum 3D7
# 2              Plasmodium falciparum D6
# 3            Plasmodium falciparum NF54
# 4   Plasmodium falciparum FcB1/Columbia
# ..                                  ...
# 71                Plasmodium falciparum
# 72                Plasmodium falciparum
# 73                Plasmodium falciparum
# 74                Plasmodium falciparum
# 75                Plasmodium falciparum
#
#                                           pref_name  score  \
# 0                             Plasmodium falciparum   28.0
# 1                         Plasmodium falciparum 3D7   24.0
# 2                          Plasmodium falciparum D6   24.0
# 3                        Plasmodium falciparum NF54   24.0
# 4   Plasmodium falciparum (isolate FcB1 / Columbia)   19.0
# ..                                              ...    ...
# 71                                         Aldolase    8.0
# 72       HAP protein (Putative aspartic proteinase)    8.0
# 73                        Glutathione S-transferase    8.0
# 74               Calcium-dependent protein kinase 1    8.0
# 75                    CGMP-dependent protein kinase    8.0
#
#     species_group_flag target_chembl_id  \
# 0                False        CHEMBL364
# 1                False    CHEMBL2366922
# 2                False    CHEMBL2367107
# 3                False    CHEMBL2367131
# 4                False     CHEMBL612608
# ..                 ...              ...
# 71               False       CHEMBL4156
# 72               False       CHEMBL6075
# 73               False    CHEMBL1697656
# 74               False    CHEMBL1908387
# 75               False    CHEMBL2169724
#
#                                     target_components     target_type  tax_id
# 0                                                  []        ORGANISM    5833
# 1                                                  []        ORGANISM   36329
# 2                                                  []        ORGANISM  478860
# 3                                                  []        ORGANISM    5843
# 4                                                  []        ORGANISM  186763
# ..                                                ...             ...     ...
# 71  [{'accession': 'Q27744', 'component_descriptio...  SINGLE PROTEIN    5833
# 72  [{'accession': 'Q9Y006', 'component_descriptio...  SINGLE PROTEIN    5833
# 73  [{'accession': 'Q8ILQ7', 'component_descriptio...  SINGLE PROTEIN    5833
# 74  [{'accession': 'P62344', 'component_descriptio...  SINGLE PROTEIN    5833
# 75  [{'accession': 'W7JX98', 'component_descriptio...  SINGLE PROTEIN    5833
#
# [76 rows x 9 columns]

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Plasmodium falciparum* (first entry)**

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL364'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Plasmodium falciparum* (CHEMBL364) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 0                 None        32325                  []    CHEMBL764090
# 1                 None        32480                  []    CHEMBL760652
# 2                 None        33480                  []    CHEMBL764090
# 3                 None        34739                  []    CHEMBL764090
# 4                 None        34877                  []    CHEMBL760652
# ...                ...          ...                 ...             ...
# 43319             None     23681266                  []   CHEMBL4888493
# 43320             None     23681267                  []   CHEMBL4888493
# 43321             None     23681268                  []   CHEMBL4888493
# 43322             None     23681269                  []   CHEMBL4888493
# 43323             None     23681270                  []   CHEMBL4888493
#
#                                        assay_description assay_type  \
# 0      Growth inhibition of chloroquine-resistant Pla...          F
# 1      In vitro antimalarial activity against Plasmod...          F
# 2      Growth inhibition of chloroquine-resistant Pla...          F
# 3      Growth inhibition of chloroquine-resistant Pla...          F
# 4      In vitro antimalarial activity against Plasmod...          F
# ...                                                  ...        ...
# 43319  Re-testing in dose-response curve in 3D7 pLDH ...          F
# 43320  Re-testing in dose-response curve in 3D7 pLDH ...          F
# 43321  Re-testing in dose-response curve in 3D7 pLDH ...          F
# 43322  Re-testing in dose-response curve in 3D7 pLDH ...          F
# 43323  Re-testing in dose-response curve in 3D7 pLDH ...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 0                        None                   None  BAO_0000190
# 1                        None                   None  BAO_0000190
# 2                        None                   None  BAO_0000190
# 3                        None                   None  BAO_0000190
# 4                        None                   None  BAO_0000190
# ...                       ...                    ...          ...
# 43319                    None                   None  BAO_0000190
# 43320                    None                   None  BAO_0000190
# 43321                    None                   None  BAO_0000190
# 43322                    None                   None  BAO_0000190
# 43323                    None                   None  BAO_0000190
#
#         bao_format  ...        target_organism       target_pref_name  \
# 0      BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 1      BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 2      BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 3      BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 4      BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# ...            ...  ...                    ...                    ...
# 43319  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 43320  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 43321  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 43322  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 43323  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
#
#       target_tax_id text_value  toid  type  units    uo_units upper_value  \
# 0              5833       None  None  IC50     uM  UO_0000065        None
# 1              5833       None  None  IC50     nM  UO_0000065        None
# 2              5833       None  None  IC50     uM  UO_0000065        None
# 3              5833       None  None  IC50     uM  UO_0000065        None
# 4              5833       None  None  IC50      M  UO_0000065        None
# ...             ...        ...   ...   ...    ...         ...         ...
# 43319          5833       None  None  IC50     uM  UO_0000065        None
# 43320          5833       None  None  IC50     uM  UO_0000065        None
# 43321          5833       None  None  IC50     uM  UO_0000065        None
# 43322          5833       None  None  IC50     uM  UO_0000065        None
# 43323          5833       None  None  IC50     uM  UO_0000065        None
#
#             value
# 0            73.5
# 1            4.25
# 2            22.5
# 3           200.0
# 4      0.00000566
# ...           ...
# 43319        25.0
# 43320       0.416
# 43321       0.444
# 43322        1.32
# 43323        1.15
#
# [43324 rows x 45 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('Plasmodium_falciparum_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 1                 None        32480                  []    CHEMBL760652
# 4                 None        34877                  []    CHEMBL760652
# 5                 None        34878                  []    CHEMBL760652
# 11                None        37328                  []    CHEMBL760652
# 12                None        37329                  []    CHEMBL760653
# ...                ...          ...                 ...             ...
# 43319             None     23681266                  []   CHEMBL4888493
# 43320             None     23681267                  []   CHEMBL4888493
# 43321             None     23681268                  []   CHEMBL4888493
# 43322             None     23681269                  []   CHEMBL4888493
# 43323             None     23681270                  []   CHEMBL4888493
#
#                                        assay_description assay_type  \
# 1      In vitro antimalarial activity against Plasmod...          F
# 4      In vitro antimalarial activity against Plasmod...          F
# 5      In vitro antimalarial activity against Plasmod...          F
# 11     In vitro antimalarial activity against Plasmod...          F
# 12     In vitro antimalarial activity against Plasmod...          F
# ...                                                  ...        ...
# 43319  Re-testing in dose-response curve in 3D7 pLDH ...          F
# 43320  Re-testing in dose-response curve in 3D7 pLDH ...          F
# 43321  Re-testing in dose-response curve in 3D7 pLDH ...          F
# 43322  Re-testing in dose-response curve in 3D7 pLDH ...          F
# 43323  Re-testing in dose-response curve in 3D7 pLDH ...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 1                        None                   None  BAO_0000190
# 4                        None                   None  BAO_0000190
# 5                        None                   None  BAO_0000190
# 11                       None                   None  BAO_0000190
# 12                       None                   None  BAO_0000190
# ...                       ...                    ...          ...
# 43319                    None                   None  BAO_0000190
# 43320                    None                   None  BAO_0000190
# 43321                    None                   None  BAO_0000190
# 43322                    None                   None  BAO_0000190
# 43323                    None                   None  BAO_0000190
#
#         bao_format  ...        target_organism       target_pref_name  \
# 1      BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 4      BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 5      BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 11     BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 12     BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# ...            ...  ...                    ...                    ...
# 43319  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 43320  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 43321  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 43322  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 43323  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
#
#       target_tax_id text_value  toid  type  units    uo_units upper_value  \
# 1              5833       None  None  IC50     nM  UO_0000065        None
# 4              5833       None  None  IC50      M  UO_0000065        None
# 5              5833       None  None  IC50      M  UO_0000065        None
# 11             5833       None  None  IC50     nM  UO_0000065        None
# 12             5833       None  None  IC50     nM  UO_0000065        None
# ...             ...        ...   ...   ...    ...         ...         ...
# 43319          5833       None  None  IC50     uM  UO_0000065        None
# 43320          5833       None  None  IC50     uM  UO_0000065        None
# 43321          5833       None  None  IC50     uM  UO_0000065        None
# 43322          5833       None  None  IC50     uM  UO_0000065        None
# 43323          5833       None  None  IC50     uM  UO_0000065        None
#
#             value
# 1            4.25
# 4      0.00000566
# 5       0.0000176
# 11           9.55
# 12           16.8
# ...           ...
# 43319        25.0
# 43320       0.416
# 43321       0.444
# 43322        1.32
# 43323        1.15
#
# [41714 rows x 45 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 20664

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#       activity_comment  activity_id activity_properties assay_chembl_id  \
# 1                 None        32480                  []    CHEMBL760652
# 4                 None        34877                  []    CHEMBL760652
# 5                 None        34878                  []    CHEMBL760652
# 11                None        37328                  []    CHEMBL760652
# 13                None        38263                  []    CHEMBL762998
# ...                ...          ...                 ...             ...
# 41809             None     23679273                  []   CHEMBL4888488
# 41810             None     23679274                  []   CHEMBL4888488
# 41811             None     23679275                  []   CHEMBL4888488
# 41812             None     23679276                  []   CHEMBL4888488
# 41813             None     23679277                  []   CHEMBL4888488
#
#                                        assay_description assay_type  \
# 1      In vitro antimalarial activity against Plasmod...          F
# 4      In vitro antimalarial activity against Plasmod...          F
# 5      In vitro antimalarial activity against Plasmod...          F
# 11     In vitro antimalarial activity against Plasmod...          F
# 13     Antimalarial activity against Plasmodium falci...          F
# ...                                                  ...        ...
# 41809  Hit confirmation in dose-response curve in NF5...          F
# 41810  Hit confirmation in dose-response curve in NF5...          F
# 41811  Hit confirmation in dose-response curve in NF5...          F
# 41812  Hit confirmation in dose-response curve in NF5...          F
# 41813  Hit confirmation in dose-response curve in NF5...          F
#
#       assay_variant_accession assay_variant_mutation bao_endpoint  \
# 1                        None                   None  BAO_0000190
# 4                        None                   None  BAO_0000190
# 5                        None                   None  BAO_0000190
# 11                       None                   None  BAO_0000190
# 13                       None                   None  BAO_0000190
# ...                       ...                    ...          ...
# 41809                    None                   None  BAO_0000190
# 41810                    None                   None  BAO_0000190
# 41811                    None                   None  BAO_0000190
# 41812                    None                   None  BAO_0000190
# 41813                    None                   None  BAO_0000190
#
#         bao_format  ...        target_organism       target_pref_name  \
# 1      BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 4      BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 5      BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 11     BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 13     BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# ...            ...  ...                    ...                    ...
# 41809  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 41810  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 41811  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 41812  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
# 41813  BAO_0000218  ...  Plasmodium falciparum  Plasmodium falciparum
#
#       target_tax_id text_value  toid  type  units    uo_units upper_value  \
# 1              5833       None  None  IC50     nM  UO_0000065        None
# 4              5833       None  None  IC50      M  UO_0000065        None
# 5              5833       None  None  IC50      M  UO_0000065        None
# 11             5833       None  None  IC50     nM  UO_0000065        None
# 13             5833       None  None  IC50     nM  UO_0000065        None
# ...             ...        ...   ...   ...    ...         ...         ...
# 41809          5833       None  None  IC50     uM  UO_0000065        None
# 41810          5833       None  None  IC50     uM  UO_0000065        None
# 41811          5833       None  None  IC50     uM  UO_0000065        None
# 41812          5833       None  None  IC50     uM  UO_0000065        None
# 41813          5833       None  None  IC50     uM  UO_0000065        None
#
#             value
# 1            4.25
# 4      0.00000566
# 5       0.0000176
# 11           9.55
# 13           18.0
# ...           ...
# 41809        1.86
# 41810        10.0
# 41811        1.66
# 41812        3.98
# 41813        2.69
#
# [20664 rows x 45 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 1            CHEMBL77052  C[C@@H]1CC[C@H]2[C@@H](C)[C@@H](OCCC3ON3C(=O)c...
# 4           CHEMBL307145                                      Oc1cccc(O)c1O
# 5            CHEMBL16300                                    O=C(NO)c1ccccc1
# 11          CHEMBL307153  C[C@@H]1CC[C@H]2[C@@H](C)[C@@H](OCCCOc3coc(CO)...
# 13          CHEMBL339049  CC(C)(C)NCc1cc(Nc2ccnc3cc(Cl)ccc23)cc(-c2ccc(C...
# ...                  ...                                                ...
# 41809      CHEMBL5024998                          Fc1cnc(OC2Cc3ccccc3C2)nc1
# 41810      CHEMBL4953418  CCn1cc(C#N)c(=O)c2cc(F)c(N3CCN(Cc4ccccc4)CC3)cc21
# 41811      CHEMBL4964239  CCC(=O)N(Cc1ccc(-c2ccc(Cl)cc2)o1)[C@H]1CCS(=O)...
# 41812      CHEMBL4939535  CC(C)N1C(=O)NC(=O)C2(Cc3ccccc3N3CCN(Cc4ccccc4)...
# 41813      CHEMBL4895640              Cc1nn(-c2nc3ccccc3[nH]2)c(O)c1CCC(C)C
#
#       standard_value
# 1               4.25
# 4             5660.0
# 5            17600.0
# 11              9.55
# 13              18.0
# ...              ...
# 41809         1860.0
# 41810        10000.0
# 41811         1660.0
# 41812         3980.0
# 41813         2690.0
#
# [20664 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('Plasmodium_falciparum_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('Plasmodium_falciparum_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) > 1000:
    bioactivity_threshold.append("inactive")
  else:
    bioactivity_threshold.append("active")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#       molecule_chembl_id                                   canonical_smiles  \
# 0            CHEMBL77052  C[C@@H]1CC[C@H]2[C@@H](C)[C@@H](OCCC3ON3C(=O)c...
# 1           CHEMBL307145                                      Oc1cccc(O)c1O
# 2            CHEMBL16300                                    O=C(NO)c1ccccc1
# 3           CHEMBL307153  C[C@@H]1CC[C@H]2[C@@H](C)[C@@H](OCCCOc3coc(CO)...
# 4           CHEMBL339049  CC(C)(C)NCc1cc(Nc2ccnc3cc(Cl)ccc23)cc(-c2ccc(C...
# ...                  ...                                                ...
# 20659      CHEMBL5024998                          Fc1cnc(OC2Cc3ccccc3C2)nc1
# 20660      CHEMBL4953418  CCn1cc(C#N)c(=O)c2cc(F)c(N3CCN(Cc4ccccc4)CC3)cc21
# 20661      CHEMBL4964239  CCC(=O)N(Cc1ccc(-c2ccc(Cl)cc2)o1)[C@H]1CCS(=O)...
# 20662      CHEMBL4939535  CC(C)N1C(=O)NC(=O)C2(Cc3ccccc3N3CCN(Cc4ccccc4)...
# 20663      CHEMBL4895640              Cc1nn(-c2nc3ccccc3[nH]2)c(O)c1CCC(C)C
#
#        standard_value     class
# 0                4.25    active
# 1             5660.00  inactive
# 2            17600.00  inactive
# 3                9.55    active
# 4               18.00    active
# ...               ...       ...
# 20659         1860.00  inactive
# 20660        10000.00  inactive
# 20661         1660.00  inactive
# 20662         3980.00  inactive
# 20663         2690.00  inactive
#
# [20664 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('Plasmodium_falciparum_03_bioactivity_data_curated.csv', index=False)

# %%
! zip Plasmodium_falciparum.zip *.csv
# Out:
#   adding: Plasmodium_falciparum_01_bioactivity_data_raw.csv (deflated 93%)
#   adding: Plasmodium_falciparum_02_bioactivity_data_preprocessed.csv (deflated 81%)
#   adding: Plasmodium_falciparum_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 28224
# drwx------ 5 root root     4096 Sep 29 13:23 drive
# -rw-r--r-- 1 root root 23290672 Sep 29 13:29 Plasmodium_falciparum_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  1629272 Sep 29 13:34 Plasmodium_falciparum_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  1793201 Sep 29 13:39 Plasmodium_falciparum_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  2171858 Sep 29 13:39 Plasmodium_falciparum.zip
# drwxr-xr-x 1 root root     4096 Sep 26 13:45 sample_data
