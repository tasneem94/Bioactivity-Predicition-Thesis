# %% [markdown]
# <a href="https://colab.research.google.com/github/tasneem94/Bioactivity-Predicition-Thesis/blob/main/Thesis_05_Leukocyte_elastase_lazy_Compare_ML_Classifications_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **1. Import libraries**

# %%
! pip install lazypredict
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting lazypredict
#   Downloading lazypredict-0.2.12-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from lazypredict) (4.64.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from lazypredict) (7.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.3.5)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from lazypredict) (1.1.0)
# Requirement already satisfied: lightgbm in /usr/local/lib/python3.7/dist-packages (from lazypredict) (2.2.3)
# Requirement already satisfied: xgboost in /usr/local/lib/python3.7/dist-packages (from lazypredict) (0.90)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from lightgbm->lazypredict) (1.21.6)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from lightgbm->lazypredict) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->lazypredict) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->lazypredict) (2022.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->lazypredict) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->lazypredict) (3.1.0)
# Installing collected packages: lazypredict
# Successfully installed lazypredict-0.2.12

# %%
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split
import lazypredict
from lazypredict.Supervised import LazyClassifier

# %% [markdown]
# ## **2. Load the data set**

# %%
df = pd.read_csv('/content/Leukocyte_elastase_09_bioactivity_data_2class_binary_active_inactive_pubchem_fp.csv')

# %%
X = df.drop('target', axis=1)
Y = df.target

# %% [markdown]
# ## **3. Data pre-processing**

# %%
# Examine X dimension
X.shape
# Out:
# (1804, 881)

# %%
# Remove low variance features
from sklearn.feature_selection import VarianceThreshold
selection = VarianceThreshold(threshold=(.8 * (1 - .8)))    
X = selection.fit_transform(X)
X.shape
# Out:
# (1804, 151)

# %%
# Perform data splitting using 80/20 ratio
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=100)

# %% [markdown]
# ## **4. Compare ML algorithms**

# %%
# Defines and builds the lazyclassifier
clf = LazyClassifier(verbose=0,ignore_warnings=True, custom_metric=None)
models_train,predictions_train = clf.fit(X_train, X_train, Y_train, Y_train)
models_test,predictions_test = clf.fit(X_train, X_test, Y_train, Y_test)
# Out:
# 100%|██████████| 29/29 [00:05<00:00,  5.31it/s]
# 'tuple' object has no attribute '__name__'
# Invalid Classifier(s)
# 100%|██████████| 29/29 [00:04<00:00,  5.97it/s]

# %%
# Performance table of the training set (80% subset)
predictions_train
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# DecisionTreeClassifier             0.97               0.97     0.97      0.97
# ExtraTreeClassifier                0.97               0.97     0.97      0.97
# ExtraTreesClassifier               0.97               0.97     0.97      0.97
# LabelPropagation                   0.97               0.97     0.97      0.97
# LabelSpreading                     0.97               0.97     0.97      0.97
# RandomForestClassifier             0.97               0.96     0.96      0.97
# LGBMClassifier                     0.97               0.96     0.96      0.97
# BaggingClassifier                  0.97               0.96     0.96      0.97
# XGBClassifier                      0.93               0.91     0.91      0.93
# QuadraticDiscriminantAnalysis      0.86               0.91     0.91      0.87
# SVC                                0.93               0.91     0.91      0.93
# LinearSVC                          0.92               0.89     0.89      0.92
# LogisticRegression                 0.91               0.88     0.88      0.91
# KNeighborsClassifier               0.92               0.88     0.88      0.92
# LinearDiscriminantAnalysis         0.91               0.87     0.87      0.91
# CalibratedClassifierCV             0.92               0.87     0.87      0.92
# RidgeClassifier                    0.91               0.87     0.87      0.91
# RidgeClassifierCV                  0.91               0.87     0.87      0.91
# AdaBoostClassifier                 0.88               0.84     0.84      0.88
# PassiveAggressiveClassifier        0.89               0.83     0.83      0.88
# GaussianNB                         0.79               0.82     0.82      0.80
# BernoulliNB                        0.78               0.81     0.81      0.79
# NearestCentroid                    0.77               0.80     0.80      0.79
# SGDClassifier                      0.89               0.80     0.80      0.88
# Perceptron                         0.84               0.73     0.73      0.83
# DummyClassifier                    0.77               0.50     0.50      0.67
#
#                                Time Taken
# Model
# DecisionTreeClassifier               0.05
# ExtraTreeClassifier                  0.03
# ExtraTreesClassifier                 0.32
# LabelPropagation                     0.23
# LabelSpreading                       0.27
# RandomForestClassifier               0.35
# LGBMClassifier                       0.30
# BaggingClassifier                    0.15
# XGBClassifier                        0.58
# QuadraticDiscriminantAnalysis        0.08
# SVC                                  0.26
# LinearSVC                            0.34
# LogisticRegression                   0.11
# KNeighborsClassifier                 0.15
# LinearDiscriminantAnalysis           0.13
# CalibratedClassifierCV               1.29
# RidgeClassifier                      0.04
# RidgeClassifierCV                    0.07
# AdaBoostClassifier                   0.30
# PassiveAggressiveClassifier          0.06
# GaussianNB                           0.03
# BernoulliNB                          0.04
# NearestCentroid                      0.04
# SGDClassifier                        0.06
# Perceptron                           0.04
# DummyClassifier                      0.03

# %%
# Performance table of the test set (20% subset)
predictions_test
# Out:
#                                Accuracy  Balanced Accuracy  ROC AUC  F1 Score  \
# Model
# QuadraticDiscriminantAnalysis      0.78               0.84     0.84      0.80
# LinearDiscriminantAnalysis         0.87               0.84     0.84      0.87
# RidgeClassifier                    0.86               0.83     0.83      0.87
# RidgeClassifierCV                  0.86               0.83     0.83      0.87
# GaussianNB                         0.75               0.82     0.82      0.77
# SVC                                0.85               0.82     0.82      0.86
# ExtraTreesClassifier               0.84               0.81     0.81      0.85
# KNeighborsClassifier               0.86               0.81     0.81      0.86
# LogisticRegression                 0.86               0.81     0.81      0.86
# CalibratedClassifierCV             0.87               0.81     0.81      0.87
# DecisionTreeClassifier             0.86               0.81     0.81      0.86
# LGBMClassifier                     0.85               0.80     0.80      0.85
# LabelPropagation                   0.82               0.80     0.80      0.83
# LabelSpreading                     0.82               0.80     0.80      0.83
# XGBClassifier                      0.83               0.80     0.80      0.84
# BernoulliNB                        0.73               0.80     0.80      0.76
# LinearSVC                          0.84               0.80     0.80      0.85
# NearestCentroid                    0.73               0.80     0.80      0.76
# ExtraTreeClassifier                0.84               0.80     0.80      0.84
# AdaBoostClassifier                 0.83               0.80     0.80      0.84
# RandomForestClassifier             0.84               0.79     0.79      0.85
# BaggingClassifier                  0.84               0.79     0.79      0.84
# SGDClassifier                      0.83               0.72     0.72      0.83
# PassiveAggressiveClassifier        0.81               0.72     0.72      0.81
# Perceptron                         0.82               0.70     0.70      0.81
# DummyClassifier                    0.79               0.50     0.50      0.70
#
#                                Time Taken
# Model
# QuadraticDiscriminantAnalysis        0.07
# LinearDiscriminantAnalysis           0.10
# RidgeClassifier                      0.03
# RidgeClassifierCV                    0.07
# GaussianNB                           0.03
# SVC                                  0.17
# ExtraTreesClassifier                 0.30
# KNeighborsClassifier                 0.05
# LogisticRegression                   0.11
# CalibratedClassifierCV               1.28
# DecisionTreeClassifier               0.05
# LGBMClassifier                       0.28
# LabelPropagation                     0.16
# LabelSpreading                       0.21
# XGBClassifier                        0.48
# BernoulliNB                          0.04
# LinearSVC                            0.33
# NearestCentroid                      0.03
# ExtraTreeClassifier                  0.03
# AdaBoostClassifier                   0.27
# RandomForestClassifier               0.35
# BaggingClassifier                    0.13
# SGDClassifier                        0.06
# PassiveAggressiveClassifier          0.05
# Perceptron                           0.04
# DummyClassifier                      0.03

# %% [markdown]
# ## **5. Data visualization of model performance**

# %%
# Bar plot of Accuracy values
import matplotlib.pyplot as plt
import seaborn as sns

#train["Accuracy"] = [0 if i < 0 else i for i in train.iloc[:,0] ]

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Accuracy", data=predictions_train)
ax.set(xlim=(0, 1))
# Out:
# [(0.0, 1.0)]

# %%
# Bar plot of ROC AUC values
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="ROC AUC", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]

# %%
# Bar plot of calculation time
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(5, 10))
sns.set_theme(style="whitegrid")
ax = sns.barplot(y=predictions_train.index, x="Time Taken", data=predictions_train)
ax.set(xlim=(0, 10))
# Out:
# [(0.0, 10.0)]
